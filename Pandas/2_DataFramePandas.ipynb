# %%
import pandas as pd
import numpy as np

# %%
data=np.random.randn(4,3)

# %%
data
# Out:
# array([[-0.6042605 , -1.01253978, -0.676614  ],
#        [ 0.52170257,  0.93667831,  0.87147348],
#        [ 0.08480616,  1.06678966,  1.69205755],
#        [-1.49395651,  1.95843559,  1.08914227]])

# %%
dataFrame = pd.DataFrame(data)

# %%
dataFrame
# Out:
#           0         1         2
# 0 -0.604260 -1.012540 -0.676614
# 1  0.521703  0.936678  0.871473
# 2  0.084806  1.066790  1.692058
# 3 -1.493957  1.958436  1.089142

# %%
dataFrame[0]
#ilk klon gelir
# Out:
# 0   -0.604260
# 1    0.521703
# 2    0.084806
# 3   -1.493957
# Name: 0, dtype: float64

# %%
newdataframe= pd.DataFrame(data,index=["fatmanur","zeynep","atlas","mehmet"],columns=["maas","yas","calisma saati"])

# %%
newdataframe
# Out:
#               maas       yas  calisma saati
# fatmanur -0.604260 -1.012540      -0.676614
# zeynep    0.521703  0.936678       0.871473
# atlas     0.084806  1.066790       1.692058
# mehmet   -1.493957  1.958436       1.089142

# %%
newdataframe[["maas","yas"]]
# Out:
#               maas       yas
# fatmanur -0.604260 -1.012540
# zeynep    0.521703  0.936678
# atlas     0.084806  1.066790
# mehmet   -1.493957  1.958436

# %%
newdataframe.loc["fatmanur"]
# Out:
# maas            -0.604260
# yas             -1.012540
# calisma saati   -0.676614
# Name: fatmanur, dtype: float64

# %%
newdataframe.iloc[1]
# Out:
# maas             0.521703
# yas              0.936678
# calisma saati    0.871473
# Name: zeynep, dtype: float64

# %%
newdataframe
# Out:
#               maas       yas  calisma saati
# fatmanur -0.604260 -1.012540      -0.676614
# zeynep    0.521703  0.936678       0.871473
# atlas     0.084806  1.066790       1.692058
# mehmet   -1.493957  1.958436       1.089142

# %%
newdataframe["emeklilik yasi"]=newdataframe["yas"]+newdataframe["yas"]

# %%
newdataframe
# Out:
#               maas       yas  calisma saati  emeklilik yasi
# fatmanur -0.604260 -1.012540      -0.676614       -2.025080
# zeynep    0.521703  0.936678       0.871473        1.873357
# atlas     0.084806  1.066790       1.692058        2.133579
# mehmet   -1.493957  1.958436       1.089142        3.916871

# %%
newdataframe.drop("emeklilik yasi", axis =1)
#kolon silmek için axis 1 olmalı
# Out:
#               maas       yas  calisma saati
# fatmanur -0.604260 -1.012540      -0.676614
# zeynep    0.521703  0.936678       0.871473
# atlas     0.084806  1.066790       1.692058
# mehmet   -1.493957  1.958436       1.089142

# %%
newdataframe.drop("mehmet",axis=0)
#satır silmek için axis 0 olmalı
# Out:
#               maas       yas  calisma saati  emeklilik yasi
# fatmanur -0.604260 -1.012540      -0.676614       -2.025080
# zeynep    0.521703  0.936678       0.871473        1.873357
# atlas     0.084806  1.066790       1.692058        2.133579

# %%
newdataframe
# Out:
#               maas       yas  calisma saati  emeklilik yasi
# fatmanur -0.604260 -1.012540      -0.676614       -2.025080
# zeynep    0.521703  0.936678       0.871473        1.873357
# atlas     0.084806  1.066790       1.692058        2.133579
# mehmet   -1.493957  1.958436       1.089142        3.916871

# %%
#yukarıda tamamen silinmedi tamamen silmek için inplace kullanılır
newdataframe.drop("emeklilik yasi", axis=1, inplace=True)

# %%
newdataframe
# Out:
#               maas       yas  calisma saati
# fatmanur -0.604260 -1.012540      -0.676614
# zeynep    0.521703  0.936678       0.871473
# atlas     0.084806  1.066790       1.692058
# mehmet   -1.493957  1.958436       1.089142

# %%
newdataframe.loc["fatmanur"]["yas"]
# Out:
# -1.012539778042099

# %%
newdataframe.loc["atlas","yas"]
# Out:
# 1.066789656001072

# %%
newdataframe <0
# Out:
#            maas    yas  calisma saati
# fatmanur   True   True           True
# zeynep    False  False          False
# atlas     False  False          False
# mehmet     True  False          False

# %%
booleanframe= newdataframe<0

# %%
newdataframe[booleanframe]
# Out:
#               maas      yas  calisma saati
# fatmanur -0.604260 -1.01254      -0.676614
# zeynep         NaN      NaN            NaN
# atlas          NaN      NaN            NaN
# mehmet   -1.493957      NaN            NaN

# %%
newdataframe[newdataframe<0]
# Out:
#               maas      yas  calisma saati
# fatmanur -0.604260 -1.01254      -0.676614
# zeynep         NaN      NaN            NaN
# atlas          NaN      NaN            NaN
# mehmet   -1.493957      NaN            NaN

# %%
newindexlist=["fat","zey","atl","meh"]

# %%
newdataframe["yeni index"]= newindexlist

# %%
newdataframe
# Out:
#               maas       yas  calisma saati yeni index
# fatmanur -0.604260 -1.012540      -0.676614        fat
# zeynep    0.521703  0.936678       0.871473        zey
# atlas     0.084806  1.066790       1.692058        atl
# mehmet   -1.493957  1.958436       1.089142        meh

# %%
newdataframe.set_index("yeni index")
# Out:
#                 maas       yas  calisma saati
# yeni index
# fat        -0.604260 -1.012540      -0.676614
# zey         0.521703  0.936678       0.871473
# atl         0.084806  1.066790       1.692058
# meh        -1.493957  1.958436       1.089142

# %%
newdataframe
# Out:
#               maas       yas  calisma saati yeni index
# fatmanur -0.604260 -1.012540      -0.676614        fat
# zeynep    0.521703  0.936678       0.871473        zey
# atlas     0.084806  1.066790       1.692058        atl
# mehmet   -1.493957  1.958436       1.089142        meh

# %%
newdataframe.set_index("yeni index", inplace= True)

# %%
newdataframe
# Out:
#                 maas       yas  calisma saati
# yeni index
# fat        -0.604260 -1.012540      -0.676614
# zey         0.521703  0.936678       0.871473
# atl         0.084806  1.066790       1.692058
# meh        -1.493957  1.958436       1.089142

# %%
ilkindexler=["simpson","simpson","simpson","south park","south park","south park"]

# %%
icindexler=["homer","bart","merge","cartman","kenny","kyle"]

# %%
birlesmisindex=list(zip(ilkindexler,icindexler))

# %%
birlesmisindex
# Out:
# [('simpson', 'homer'),
#  ('simpson', 'bart'),
#  ('simpson', 'merge'),
#  ('south park', 'cartman'),
#  ('south park', 'kenny'),
#  ('south park', 'kyle')]

# %%
birlesmisindex=pd.MultiIndex.from_tuples(birlesmisindex)

# %%
birlesmisindex
# Out:
# MultiIndex([(   'simpson',   'homer'),
#             (   'simpson',    'bart'),
#             (   'simpson',   'merge'),
#             ('south park', 'cartman'),
#             ('south park',   'kenny'),
#             ('south park',    'kyle')],
#            )

# %%
benimcizgifilmlistem=[[40,"a"],[10,"b"],[30,"c"],[9,"d"],[10,"e"],[11,"f"]]

# %%
cizgifilmnumpydizi=np.array(benimcizgifilmlistem)

# %%
cizgifilmdataframe= pd.DataFrame(cizgifilmnumpydizi,index=birlesmisindex, columns=["yas","meslek"])

# %%
cizgifilmdataframe
# Out:
#                    yas meslek
# simpson    homer    40      a
#            bart     10      b
#            merge    30      c
# south park cartman   9      d
#            kenny    10      e
#            kyle     11      f

# %%
cizgifilmdataframe.loc["simpson"]
# Out:
#       yas meslek
# homer  40      a
# bart   10      b
# merge  30      c

# %%
cizgifilmdataframe.loc["south park"].loc["kenny"]
# Out:
# yas       10
# meslek     e
# Name: kenny, dtype: object

# %%
cizgifilmdataframe.index.names=["film adi","isim"]

# %%
cizgifilmdataframe
# Out:
#                    yas meslek
# film adi   isim
# simpson    homer    40      a
#            bart     10      b
#            merge    30      c
# south park cartman   9      d
#            kenny    10      e
#            kyle     11      f
