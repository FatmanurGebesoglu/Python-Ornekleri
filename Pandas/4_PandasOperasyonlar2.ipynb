# %%
import numpy as np
import pandas as pd

# %%
sozluk1={"isim":["ahmet","mehmet","zeynep","atil"],
         "spor":["kosu","yüzme","kosu","basketbol"],
         "kalori":[100,200,300,400]}

# %%
dataFrame1=pd.DataFrame(sozluk1,index=[0,1,2,3])

# %%
dataFrame1
# Out:
#      isim       spor  kalori
# 0   ahmet       kosu     100
# 1  mehmet      yüzme     200
# 2  zeynep       kosu     300
# 3    atil  basketbol     400

# %%
sozluk2={"isim":["osman","levent","atlas","fatma"],
         "spor":["kosu","yüzme","kosu","basketbol"],
         "kalori":[200,100,50,400]}

# %%
dataFrame2=pd.DataFrame(sozluk2,index=[4,5,6,7])

# %%
sozluk3={"isim":["ayse","mahmut","duygu","nur"],
         "spor":["kosu","yüzme","badminton","tenis"],
         "kalori":[100,200,800,500]}

# %%
dataFrame3=pd.DataFrame(sozluk3,index=[8,9,10,11])

# %%
dataFrame1
# Out:
#      isim       spor  kalori
# 0   ahmet       kosu     100
# 1  mehmet      yüzme     200
# 2  zeynep       kosu     300
# 3    atil  basketbol     400

# %%
dataFrame2
# Out:
#      isim       spor  kalori
# 4   osman       kosu     200
# 5  levent      yüzme     100
# 6   atlas       kosu      50
# 7   fatma  basketbol     400

# %%
dataFrame3
# Out:
#       isim       spor  kalori
# 8     ayse       kosu     100
# 9   mahmut      yüzme     200
# 10   duygu  badminton     800
# 11     nur      tenis     500

# %% [markdown]
# concatenation

# %%
pd.concat([dataFrame1,dataFrame2,dataFrame3],axis=0)
# Out:
#       isim       spor  kalori
# 0    ahmet       kosu     100
# 1   mehmet      yüzme     200
# 2   zeynep       kosu     300
# 3     atil  basketbol     400
# 4    osman       kosu     200
# 5   levent      yüzme     100
# 6    atlas       kosu      50
# 7    fatma  basketbol     400
# 8     ayse       kosu     100
# 9   mahmut      yüzme     200
# 10   duygu  badminton     800
# 11     nur      tenis     500

# %% [markdown]
# merge

# %%
mergesozluk1={"isim":["ahmet","mehmet","zeynep","atil"],
              "spor":["kosu","yuzme","kosu","basketbol"]}

# %%
mergeDataFrame1=pd.DataFrame(mergesozluk1)

# %%
mergeDataFrame1
# Out:
#      isim       spor
# 0   ahmet       kosu
# 1  mehmet      yuzme
# 2  zeynep       kosu
# 3    atil  basketbol

# %%
mergesozluk2={"isim":["ahmet","mehmet","zeynep","atil"],
              "spor":[100,200,150,250]}

# %%
mergeDataFrame2=pd.DataFrame(mergesozluk2)

# %%
mergeDataFrame2
# Out:
#      isim  spor
# 0   ahmet   100
# 1  mehmet   200
# 2  zeynep   150
# 3    atil   250

# %%
pd.merge(mergeDataFrame1, mergeDataFrame2, on="isim")
#isim üzerinde 2 dataframe i birleştirdik
# Out:
#      isim     spor_x  spor_y
# 0   ahmet       kosu     100
# 1  mehmet      yuzme     200
# 2  zeynep       kosu     150
# 3    atil  basketbol     250

# %%
maasSozluk={"isim":["fatmanur","zeynep","mehmet","ali"],
            "departman":["yazilim","satis","pazarlama","yazilim"],
            "maas":[200,300,400,500]}

# %%
maasDataFrame=pd.DataFrame(maasSozluk)

# %%
maasDataFrame
# Out:
#        isim  departman  maas
# 0  fatmanur    yazilim   200
# 1    zeynep      satis   300
# 2    mehmet  pazarlama   400
# 3       ali    yazilim   500

# %%
maasDataFrame["departman"].unique()
#her bir departmanı bir kez yazdırı
# Out:
# array(['yazilim', 'satis', 'pazarlama'], dtype=object)

# %%
maasDataFrame["departman"].nunique()
#kaç çeşit departman var onları yazdırır
# Out:
# 3

# %%
maasDataFrame["departman"].value_counts()
#her bir departmandan kaç tane var onu yazdırır
# Out:
# yazilim      2
# satis        1
# pazarlama    1
# Name: departman, dtype: int64

# %%
def bruttenNete(maas):
  return maas * 0.66

# %%
maasDataFrame["maas"].apply(bruttenNete)
# Out:
# 0    132.0
# 1    198.0
# 2    264.0
# 3    330.0
# Name: maas, dtype: float64

# %%
maasDataFrame.isnull()
# Out:
#     isim  departman   maas
# 0  False      False  False
# 1  False      False  False
# 2  False      False  False
# 3  False      False  False

# %%
newdata={"karakter sınıfı":["south park","south park", "simpson","simpson","simpson"],
         "karakter ismi": ["cartman","kenny","homer","bart","bart"],
         "karakter yas": [9,10,50,20,10]}

# %%
karakterDF= pd.DataFrame(newdata)

# %%
karakterDF
# Out:
#   karakter sınıfı karakter ismi  karakter yas
# 0      south park       cartman             9
# 1      south park         kenny            10
# 2         simpson         homer            50
# 3         simpson          bart            20
# 4         simpson          bart            10

# %%
karakterDF.pivot_table(values = "karakter yas",index=["karakter sınıfı","karakter ismi"],aggfunc=np.sum)
# Out:
#                                karakter yas
# karakter sınıfı karakter ismi
# simpson         bart                     30
#                 homer                    50
# south park      cartman                   9
#                 kenny                    10
