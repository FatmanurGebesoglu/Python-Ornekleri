# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
numpydizisi=np.linspace(0,10,20)

# %%
numpydizisi
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpydizisi2=numpydizisi ** 2

# %%
(benimfigur, benimeksen)= plt.subplots()
benimeksen.plot(numpydizisi,numpydizisi2,color="#3A95A8",alpha=0.3)
#alpha saydamlık yapar
benimeksen.plot(numpydizisi2,numpydizisi,"o")

# %%
(yenifigur,yenieksen)=plt.subplots()
yenieksen.plot(numpydizisi, numpydizisi + 2,color="blue", linewidth=5.0)
#linewidth grafik kalınlığını ayarlar
yenieksen.plot(numpydizisi, numpydizisi +3,color="yellow")
yenieksen.plot(numpydizisi, numpydizisi + 4,color="orange", linestyle="-.")
yenieksen.plot(numpydizisi, numpydizisi + 5,color="pink", linestyle=":")
yenieksen.plot(numpydizisi, numpydizisi + 6,color="green", linestyle="--")

yenieksen.plot(numpydizisi, numpydizisi + 8,color="red", linestyle="-.",marker="o",markerfacecolor="blue")

# %%
#scatter

# %%
plt.scatter(numpydizisi,numpydizisi2)

# %%
#histogram

# %%
newarray=np.random.randint(0,100,50)

# %%
newarray
# Out:
# array([22, 69,  5, 43, 93, 34, 79, 75, 46, 87,  7, 50, 37, 44, 90, 77, 98,
#        10, 70, 90, 77, 55, 34, 56, 55, 58, 92, 96, 33, 74, 25, 64, 46, 57,
#        99, 88, 59,  1, 83,  6, 99, 83, 28, 11, 71, 51, 26,  3, 25, 79])

# %%
plt.hist(newarray)
# Out:
# (array([6., 1., 5., 4., 4., 8., 2., 8., 4., 8.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <a list of 10 Patch objects>)

# %%
#boxplot

# %%
plt.boxplot(newarray)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7faaa2cfff50>],
#  'caps': [<matplotlib.lines.Line2D at 0x7faaa2cef7d0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7faaa2de9e50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7faaa2cefed0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7faaa2cffcd0>,
#   <matplotlib.lines.Line2D at 0x7faaa2d40190>]}
